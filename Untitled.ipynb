# %%
import dataset.marcap_utils as mu
import pandas as pd
import numpy as np
from sklearn import preprocessing

import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6    # matlab 차트의 기본 크기를 15,6으로 지정해 줍니다.

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = mu.marcap_date_range('2018-10-01','2018-10-31', ['009150'] )
featured_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Amount',
                          'Changes', 'ChagesRatio', 'Marcap', 'MarcapRatio', 'ForeignShares', 'ForeignRatio']
df_k200_pv = pd.pivot_table(df, index='Code', columns='Date', values=featured_columns)
print(df_k200_pv.shape)
# df_k200_pv
for col in featured_columns:
    print(col)
    print(df_k200_pv[col].min().min())
    print(df_k200_pv[col].max().max())
# df_k200_pv['Marcap'].min().min()
# df_k200_pv['Marcap'].max().max()
# df_k200_pv.isnull().any().any()
# df_k200_pv['Marcap']
# date_list = df['Date'].unique()
# df_k200_pv[date_list[0]]['000010']
# '000020' in date_list.index
# Out:
# (1, 252)
# Open
# 111500.0
# 141000.0
# High
# 118000.0
# 144000.0
# Low
# 107000.0
# 137500.0
# Close
# 112000.0
# 139000.0
# Volume
# 788334.0
# 3929471.0
# Amount
# 107503965000.0
# 442160270500.0
# Changes
# -8000.0
# 8500.0
# ChagesRatio
# -6.2
# 7.6
# Marcap
# 8365693952000.0
# 10382423744000.0
# MarcapRatio
# 0.53
# 0.61
# ForeignShares
# 15339400.0
# 20655890.0
# ForeignRatio
# 20.54
# 27.65

# %%
for col in featured_columns:
    scaler = preprocessing.MinMaxScaler()
    df_k200_pv[col] = scaler.fit_transform(df_k200_pv[col].to_numpy())
df_k200_pv
# Out:
#               Amount               ForeignRatio                Marcap  \
# Date      2018-10-01    2018-10-02   2018-10-01 2018-10-02 2018-10-01
# Code
# 000020  1.612930e-03  1.433414e-03     0.094292   0.094292   0.001046
# 000030  5.870907e-02  2.214115e-02     0.280138   0.280037   0.038396
# 000040  7.010181e-04  3.321749e-04     0.244956   0.244855   0.000255
# 000050  1.874149e-04  6.616436e-04     0.026868   0.027071   0.001197
# 000060  1.298914e-02  4.503216e-03     0.166582   0.166177   0.007488
# 000070  3.182266e-03  2.947504e-03     0.077258   0.077461   0.002906
# 000075  1.539979e-05  2.263507e-04     0.119538   0.119538   0.000056
# 000080  1.061607e-02  6.246417e-03     0.133935   0.132718   0.004030
# 000087  1.212166e-04  2.389010e-05     0.103011   0.103011   0.000055
# 000100  1.938105e-02  1.189922e-02     0.247693   0.247693   0.009766
# 000105  1.718762e-05  6.390058e-06     0.000000   0.000000   0.000182
# ...

# %%
df = pd.DataFrame(np.random.randn(10,6))
# Make a few areas have NaN values
df.iloc[1:3,1] = np.nan
df.iloc[5,3] = np.nan
df.iloc[7:9,5] = np.nan

# %%
if pd.isnull(df.at[1,1]) :
    print('nan')
else:
    print('??')
# Out:
# nan

# %%
mu.krx200_code_list
# Out:
# ['000020',
#  '000050',
#  '000070',
#  '000100',
#  '000120',
#  '000140',
#  '000150',
#  '000210',
#  '000230',
#  '000240',
#  '000270',
#  '000480',
#  '000640',
#  '000660',
#  '000670',
#  '000700',
#  '000720',
#  '000810',
#  '000880',
#  '000990',
#  '001040',
#  '001060',
#  '001120',
#  '001130',
#  '001210',
#  '001230',
#  '001430',
#  '001440',
#  '001520',
#  '001630',
#  '001680',
#  '001740',
#  '001790',
#  '001800',
#  '001940',
#  '002020',
#  '002030',
#  '002240',
#  '002270',
#  '002300',
#  '002350',
#  '002380',
#  '002390',
#  '002790',
#  '003000',
#  '003030',
#  '003120',
#  '003240',
#  '003300',
#  '003410',
#  '003480',
#  '003490',
#  '003520',
#  '003550',
#  '003570',
#  '003920',
#  '004000',
#  '004020',
#  '004130',
#  '004150',
#  '004170',
#  '004370',
#  '004430',
#  '004490',
#  '004710',
#  '004800',
#  '004990',
#  '005090',
#  '005180',
#  '005300',
#  '005380',
#  '005490',
#  '005500',
#  '005680',
#  '005930',
#  '005940',
# ...

# %%
df = mu.marcap_date_range('2017', '2018', '009150')
df.head()
# Out:
#      Code  Name    Close  Changes  ChagesRatio    Volume        Amount  \
# 0  009150  삼성전기  50500.0   -300.0         -0.6  264982.0  1.338364e+10
# 1  009150  삼성전기  52100.0   1600.0          3.2  545167.0  2.830985e+10
# 2  009150  삼성전기  51700.0   -400.0         -0.8  355343.0  1.837477e+10
# 3  009150  삼성전기  52000.0    300.0          0.6  281546.0  1.459347e+10
# 4  009150  삼성전기  51900.0   -100.0         -0.2  265249.0  1.381562e+10
#
#       Open     High      Low        Marcap  MarcapRatio      Stocks  \
# 0  50400.0  50800.0  49850.0  3.772032e+12         0.25  74693696.0
# 1  51000.0  52300.0  50800.0  3.891542e+12         0.25  74693696.0
# 2  51800.0  52100.0  51300.0  3.861664e+12         0.25  74693696.0
# 3  51900.0  52400.0  51500.0  3.884072e+12         0.25  74693696.0
# 4  52200.0  52800.0  51800.0  3.876603e+12         0.25  74693696.0
#
#    ForeignShares  ForeignRatio  Rank       Date
# 0     10964838.0         14.68  65.0 2017-01-02
# ...

# %%
df_a = mu.marcap_date_range_dateindexed('1995', '2018', '009150')
plt.plot(df_a['Close']*df_a['Stocks'])
plt.show()

# %%
df_k200 = mu.marcap_date_range('1995-01-01', '2018-10-31', mu.krx200_code_list)
df_pv = pd.pivot_table(df_k200, index='Code', columns='Date', values='Marcap')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1e5e67a30ef0> in <module>
#       1 df_k200 = mu.marcap_date_range('1995-01-01', '2018-10-31', mu.krx200_code_list)
#       2 df_pv = pd.pivot_table(df_k200, index='Code', columns='Date', values='Marcap')
# ----> 3 df_pv[df_pv['2018-10-31'] is NaN]
#
# NameError: name 'NaN' is not defined

# %%
import math
dfc = df_pv['2018-10-31']
for i, row in enumerate(dfc):
    if math.isnan(row):
        print(dfc[[i]])
#     dfc[[0]]
# Out:
# Code
# 000830   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 001300   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 003190   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 003450   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 003600   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 003640   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 003940   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 004940   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 005270   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 005280   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 008000   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 009720   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 010520   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 025850   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# 037620   NaN
# Name: 2018-10-31 00:00:00, dtype: float64
# Code
# ...

# %%
df_pv[dfc.iat[:,1] == pd.np.nan]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-2c2903b58167> in <module>
# ----> 1 df_pv[dfc.iat[:,1] == pd.np.nan]
#
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2267                 raise ValueError('Invalid call for scalar access (getting)!')
#    2268
# -> 2269         key = self._convert_key(key)
#    2270         return self.obj._get_value(*key, takeable=self._takeable)
#    2271
#
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py in _convert_key(self, key, is_setter)
#    2414         for a, i in zip(self.obj.axes, key):
#    2415             if not is_integer(i):
# -> 2416                 raise ValueError("iAt based indexing can only have integer "
#    2417                                  "indexers")
#    2418         return key
#
# ...

# %%
[3, 7] - np.array([1, 2])
# Out:
# array([2, 5])

# %%
a = np.array([[[1, 2, 3], [2, 2, 3], [3, 2, 3]], [[-1, 2, 3], [-2, 2, 3], [-3, 2, 3]]])
# a.shape
a = a[:,:-1,:]
a
# Out:
# array([[[ 1,  2,  3],
#         [ 2,  2,  3]],
#
#        [[-1,  2,  3],
#         [-2,  2,  3]]])

# %%
a = np.array([[[1, 2, 3], [2, 2, 3], [3, 2, 3]], [[-1, 2, 3], [-2, 2, 3], [-3, 2, 3]]])
a.shape
# Out:
# (2, 3, 3)

# %%
b = np.array([[[1, 2, 3]], [[-1, 2, 3]]])
b.shape
# Out:
# (2, 1, 3)

# %%
c=np.concatenate((a, b), axis=1)
c.shape
# Out:
# (2, 4, 3)
